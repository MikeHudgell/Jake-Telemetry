# %%
import rtree, pygeos
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import os
import folium

import numpy as np
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
import numpy as np
import statsmodels.api as sm
# Out:
# C:\Anaconda3\envs\geo37\lib\site-packages\geopandas\_compat.py:110: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.10.3-CAPI-1.16.1). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
data_path = 'C:/Users/mhudgell/data/dsa-jake/'
os.listdir(data_path)
# Out:
# ['1 Team & Station Trip Level Data - April 2024 - Randomised.csv',
#  'Total Number of Vehicles in Fleet - April 2024.csv',
#  'Workshop Data - April 2024 - Randomised.csv']

# %%
file_path = data_path +'1 Team & Station Trip Level Data - April 2024 - Randomised.csv'
trip = pd.read_csv(file_path)

# %%
trip.head(13)
# Out:
#    Registration                 Fleet Vehicle Function    Station       Date  \
# 0        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 1        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 2        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 3        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 4        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 5        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 6        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 7        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 8        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 9        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 10       111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 11       111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 12       111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
#
#    Time - Start Time - End  Trip Count  Miles Travelled  Hours  Speed
# 0      00:36:19   01:16:04           1             2.49   0.66   3.77
# 1      02:23:22   02:30:37           1             2.30   0.12  19.17
# 2      03:24:11   03:32:05           1             2.24   0.13  17.23
# 3      03:48:21   03:54:24           1             1.93   0.10  19.30
# 4      03:59:36   05:46:48           1            37.97   1.79  21.21
# 5      10:02:54   10:12:15           1             2.11   0.16  13.19
# 6      10:27:19   10:52:46           1             8.14   0.42  19.38
# 7      11:12:26   11:17:59           1             1.43   0.09  15.89
# 8      11:33:57   11:53:06           1             5.66   0.32  17.69
# 9      12:30:13   12:32:25           1             0.68   0.04  17.00
# 10     13:46:41   13:54:11           1             0.87   0.13   6.69
# 11     19:57:08   20:03:08           1             2.86   0.10  28.60
# 12     20:07:02   20:18:08           1             2.86   0.19  15.05

# %%
trip['label'] = ""
idx = trip.index[trip['Hours'] >= 1.0].tolist()
trip['label'].loc[idx] = "Unavailable"
# Out:
# C:\Anaconda3\envs\geo37\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
trip.head(13)
# Out:
#    Registration                 Fleet Vehicle Function    Station       Date  \
# 0        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 1        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 2        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 3        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 4        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 5        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 6        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 7        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 8        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 9        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 10       111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 11       111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 12       111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
#
#    Time - Start Time - End  Trip Count  Miles Travelled  Hours  Speed  \
# 0      00:36:19   01:16:04           1             2.49   0.66   3.77
# 1      02:23:22   02:30:37           1             2.30   0.12  19.17
# 2      03:24:11   03:32:05           1             2.24   0.13  17.23
# 3      03:48:21   03:54:24           1             1.93   0.10  19.30
# 4      03:59:36   05:46:48           1            37.97   1.79  21.21
# 5      10:02:54   10:12:15           1             2.11   0.16  13.19
# 6      10:27:19   10:52:46           1             8.14   0.42  19.38
# 7      11:12:26   11:17:59           1             1.43   0.09  15.89
# 8      11:33:57   11:53:06           1             5.66   0.32  17.69
# 9      12:30:13   12:32:25           1             0.68   0.04  17.00
# 10     13:46:41   13:54:11           1             0.87   0.13   6.69
# 11     19:57:08   20:03:08           1             2.86   0.10  28.60
# 12     20:07:02   20:18:08           1             2.86   0.19  15.05
#
#           label
# 0
# 1
# 2
# 3
# 4   Unavailable
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# 12

# %%
trip['label'].loc[trip['Hours'] <=0.2] = "Potentially Available"
# Out:
# C:\Anaconda3\envs\geo37\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
trip.head(13)
# Out:
#    Registration                 Fleet Vehicle Function    Station       Date  \
# 0        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 1        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 2        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 3        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 4        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 5        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 6        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 7        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 8        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 9        111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 10       111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 11       111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
# 12       111111  South Worcestershire           PATROL  WORCESTER  01-Apr-24
#
#    Time - Start Time - End  Trip Count  Miles Travelled  Hours  Speed  \
# 0      00:36:19   01:16:04           1             2.49   0.66   3.77
# 1      02:23:22   02:30:37           1             2.30   0.12  19.17
# 2      03:24:11   03:32:05           1             2.24   0.13  17.23
# 3      03:48:21   03:54:24           1             1.93   0.10  19.30
# 4      03:59:36   05:46:48           1            37.97   1.79  21.21
# 5      10:02:54   10:12:15           1             2.11   0.16  13.19
# 6      10:27:19   10:52:46           1             8.14   0.42  19.38
# 7      11:12:26   11:17:59           1             1.43   0.09  15.89
# 8      11:33:57   11:53:06           1             5.66   0.32  17.69
# 9      12:30:13   12:32:25           1             0.68   0.04  17.00
# 10     13:46:41   13:54:11           1             0.87   0.13   6.69
# 11     19:57:08   20:03:08           1             2.86   0.10  28.60
# 12     20:07:02   20:18:08           1             2.86   0.19  15.05
#
#                     label
# 0
# 1   Potentially Available
# 2   Potentially Available
# 3   Potentially Available
# 4             Unavailable
# 5   Potentially Available
# 6
# 7   Potentially Available
# 8
# 9   Potentially Available
# 10  Potentially Available
# 11  Potentially Available
# 12  Potentially Available
